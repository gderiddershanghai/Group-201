# %%
notebooks = [
    # "basic_features_RandForest.ipynb",
    # "basic_features_SGD.ipynb",
    # "basic_features_XGB.ipynb",
    "basic_features_KNN.ipynb",
    "basic_features_LogReg.ipynb",
]

for notebook in notebooks:
    try:
        print(f"Running {notebook}...")
        # %run $notebook
        print(f"Completed {notebook}.")
    except Exception as e:
        print(f"Error while running {notebook}: {e}")
# Out:
# Running basic_features_KNN.ipynb...
# ######### original [1]
# X_train: (1783, 15)
# y_train: (1783,)
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# /Users/yli/Library/Python/3.9/lib/python/site-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Time taken for basic statistical feature extraction: 3.50297 seconds
# output_generated: output/grid_search_KNN_original_essay[1]_20241117_2007_.txt
# ######### original [3]
# X_train: (1726, 15)
# y_train: (1726,)
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Time taken for basic statistical feature extraction: 3.59794 seconds
# output_generated: output/grid_search_KNN_original_essay[3]_20241117_2007_.txt
# ######### original [4]
# X_train: (1768, 15)
# y_train: (1768,)
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# ...
