# %%
import os
import math
import json
import time
import random
import scipy
import regex as re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import datetime
# import warnings
# import spacy
from itertools import combinations


from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD, PCA

from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score, cohen_kappa_score, mean_squared_error, make_scorer
from sklearn.base import BaseEstimator, TransformerMixin

# %%
# read the intermediate from the simple_feature_extraction script
basic_feature_train_df = pd.read_csv('basic_feature_train_data.csv') 
raw_training_set = pd.read_csv('asap-aes/training_set_rel3.tsv',sep='\t', encoding='latin1')

# %%
feature_cols = ['word_count', 'sent_count', 'char_count', 'sent_length', 'spell_err_count', 'syllabus_count',
                'FleKin_score', 'DalCha_score', 'unique_word_count', 'neg', 'neu', 'pos', 'compound', 'cohesion', 'AoA_score']

def data_selection(basic_feature_train_df, feature_cols, essay_set, text_set):
    df = basic_feature_train_df.copy()
    df = df[df['essay_set'].isin(essay_set)]
    df = df[~(df['essay_id'] == 10001)] # the text is "NO IMAGE"
    df = df[~df['cohesion'].isna()]

    if text_set == 'subset':
        X_train = df.loc[df['text_set'] != 'text_original', feature_cols]
        y_train = np.array(df.loc[df['text_set'] != 'text_original', 'domain1_score'])
    elif text_set == 'original':
        X_train = df.loc[df['text_set'] == 'text_original', feature_cols]
        y_train = np.array(df.loc[df['text_set'] == 'text_original', 'domain1_score'])
        
    print('X_train:', X_train.shape)
    print('y_train:', y_train.shape)

    return X_train, y_train

# %%
def output_to_file(results_filename, grid_search, overall_params, param_grid): 
    with open(results_filename, 'w') as f:
        # Save param_grid as a JSON object
        cv_results_serializable = {key: (value.tolist() if isinstance(value, np.ndarray) else value)
                                    for key, value in grid_search.cv_results_.items()}

        # Save param_grid and cv_results_ as a JSON object
        json.dump({
            'overall_params': overall_params,
            'param_grid': param_grid,
            'cv_results': cv_results_serializable
        }, f)

# %%
mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)  # Minimize MSE
qwk_scorer = make_scorer(cohen_kappa_score, weights="quadratic", greater_is_better=True) # maximize QWK

overall_params = {
    'model': 'SVM', 
    'text_set': 'original',      # 'subset', or 'original' 
    'essay_set': [1, 3, 4, 5, 6],          # [1, 3, 4, 5, 6]
    'scorer': 'qwk' # qwk_scorer, mse_scorer, or 'accuracy'
}

scorers = {'accuracy': 'accuracy', 
          'qwk': qwk_scorer, 
          'mse': mse_scorer}

# Define the pipeline with scaling, PCA, and SVM
pipeline = Pipeline([
    ('scaler', StandardScaler()),  # Step 1: Standardize features
    ('pca', PCA()),                # Step 2: Perform PCA
    ('svm', SVC())                 # Step 3: Fit SVM
])

# Define the parameter grid
param_grid = {
    'pca__n_components': [0.9, 0.8],                   # Number of PCA components to keep
    'svm__C': [0.001, 0.1, 1, 10],                # Regularization parameter
    'svm__gamma': ['scale', 'auto', 0.1, 0.01],   # Kernel coefficient
    'svm__kernel': ['linear', 'rbf',],            # Kernel type
}

X_train, y_train = data_selection(basic_feature_train_df, feature_cols, overall_params['essay_set'], overall_params['text_set'])

start_time = time.time()

# Perform grid search
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring=scorers[overall_params['scorer']], verbose=4)
grid_search.fit(X_train, y_train)

print(f"Time taken for basic statistical feature extraction: {(time.time() - start_time):.5f} seconds")
# display(pd.DataFrame(grid_search.cv_results_).sort_values('rank_test_score')[['param_pca__n_components', 'param_svm__C', 'param_svm__kernel', 'mean_test_score', 'rank_test_score']])

ts = datetime.datetime.now().strftime("%Y%m%d_%H%M")
results_filename = 'output/grid_search'+overall_params['model']+'_'+overall_params['text_set']+'_'+ts+'_.txt'
output_to_file(results_filename, grid_search, overall_params, param_grid)

print('output_generated:', results_filename)
with open(results_filename, 'r') as f:
    data = json.load(f)

# Extract the stored param_grid and cv_results_
overall_params, param_grid, cv_results = data['overall_params'], data['param_grid'], data['cv_results']

cv_results_df = pd.DataFrame(cv_results)
cv_results_df.sort_values('rank_test_score')[['param_pca__n_components', 'param_svm__C', 'param_svm__kernel', 'mean_test_score', 'rank_test_score']]
# Out:
# X_train: (1800, 15)
# y_train: (1800,)
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.197 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.139 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.197 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.139 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.197 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.139 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.197 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.139 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.627 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.679 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.645 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.661 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.706 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.497 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.596 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.523 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.515 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.524 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.627 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.679 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.645 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.661 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.706 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.343 total time=   0.1s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.420 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.387 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.368 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.375 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.627 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.679 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.645 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.661 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.706 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.472 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.540 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.471 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.458 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.466 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.627 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.679 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.645 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.661 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.706 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.393 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.401 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.415 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.385 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.463 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.635 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.681 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.651 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.660 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.715 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.647 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.665 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.650 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.649 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.670 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.635 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.681 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.651 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.660 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.715 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.643 total time=   0.1s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.664 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.657 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.607 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.661 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.635 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.681 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.651 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.660 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.715 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.651 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.652 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.646 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.675 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.635 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.681 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.651 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.660 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.715 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.604 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.654 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.614 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.649 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.660 total time=   0.0s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.641 total time=   0.2s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.681 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.651 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.660 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.713 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.623 total time=   0.1s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.696 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.667 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.637 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.639 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.641 total time=   0.2s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.681 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.651 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.660 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.713 total time=   0.2s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.607 total time=   0.1s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.663 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.664 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.597 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.629 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.641 total time=   0.2s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.681 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.651 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.660 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.713 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.619 total time=   0.1s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.693 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.670 total time=   0.1s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.610 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.646 total time=   0.1s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.641 total time=   0.2s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.681 total time=   0.1s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.651 total time=   0.2s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.660 total time=   0.1s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.713 total time=   0.2s
# [CV 1/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.642 total time=   0.0s
# [CV 2/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.644 total time=   0.0s
# [CV 3/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.651 total time=   0.0s
# [CV 4/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.665 total time=   0.0s
# [CV 5/5] END pca__n_components=0.9, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.687 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.189 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.134 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=scale, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.189 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.134 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=auto, svm__kernel=rbf;, score=0.000 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.189 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.134 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.1, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.179 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.087 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.189 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.134 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=linear;, score=0.153 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.001, svm__gamma=0.01, svm__kernel=rbf;, score=0.000 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.630 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.682 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.616 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.658 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.501 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.608 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.534 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.521 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=scale, svm__kernel=rbf;, score=0.537 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.630 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.682 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.616 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.658 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.371 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.399 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.398 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.360 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=auto, svm__kernel=rbf;, score=0.370 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.630 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.682 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.616 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.658 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.494 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.599 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.513 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.527 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.1, svm__kernel=rbf;, score=0.525 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.630 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.682 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.616 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.658 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.404 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.396 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.433 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.385 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=0.1, svm__gamma=0.01, svm__kernel=rbf;, score=0.465 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.641 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.693 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.652 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.663 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.641 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.662 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.638 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.630 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=scale, svm__kernel=rbf;, score=0.693 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.641 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.693 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.652 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.663 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.628 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.674 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.647 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.609 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=auto, svm__kernel=rbf;, score=0.644 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.641 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.693 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.652 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.663 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.644 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.663 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.643 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.635 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.1, svm__kernel=rbf;, score=0.703 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.641 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.693 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.652 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.663 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=linear;, score=0.700 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.613 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.651 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.603 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.640 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=1, svm__gamma=0.01, svm__kernel=rbf;, score=0.672 total time=   0.0s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.647 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.692 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.652 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.662 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=linear;, score=0.706 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.670 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.684 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.662 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.621 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=scale, svm__kernel=rbf;, score=0.688 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.647 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.692 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.652 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.662 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=linear;, score=0.706 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.644 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.673 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.619 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.604 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=auto, svm__kernel=rbf;, score=0.629 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.647 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.692 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.652 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.662 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=linear;, score=0.706 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.654 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.700 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.671 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.630 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.1, svm__kernel=rbf;, score=0.691 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.647 total time=   0.1s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.692 total time=   0.1s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.652 total time=   0.1s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.662 total time=   0.1s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=linear;, score=0.706 total time=   0.1s
# [CV 1/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.645 total time=   0.0s
# [CV 2/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.649 total time=   0.0s
# [CV 3/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.626 total time=   0.0s
# [CV 4/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.678 total time=   0.0s
# [CV 5/5] END pca__n_components=0.8, svm__C=10, svm__gamma=0.01, svm__kernel=rbf;, score=0.718 total time=   0.0s
# Time taken for basic statistical feature extraction: 17.33697 seconds
# output_generated: output/grid_searchSVM_original_20241117_0734_.txt
#     param_pca__n_components  param_svm__C param_svm__kernel  mean_test_score  \
# 60                      0.8        10.000            linear         0.671855
# 58                      0.8        10.000            linear         0.671855
# 62                      0.8        10.000            linear         0.671855
# 56                      0.8        10.000            linear         0.671855
# 54                      0.8         1.000            linear         0.669903
# ..                      ...           ...               ...              ...
# 35                      0.8         0.001               rbf         0.000000
# 3                       0.9         0.001               rbf         0.000000
# 39                      0.8         0.001               rbf         0.000000
# 1                       0.9         0.001               rbf         0.000000
# 37                      0.8         0.001               rbf         0.000000
#
#     rank_test_score
# 60                1
# 58                1
# 62                1
# 56                1
# 54                5
# ..              ...
# 35               57
# 3                57
# 39               57
# 1                57
# 37               57
#
# [64 rows x 5 columns]
